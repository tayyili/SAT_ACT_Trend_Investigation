# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# On March 2016, SAT was redesigned and was released with a new format. With varying legislative decisions, there have been changes in the participation rates within different states.
# This project aims to explore trends between the SAT and ACT participation rates and scores for years 2017-2019, seeking recommendations to improve SAT participation rates.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). Both SAT and ACT have different score ranges:
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Colleges and universities accept both the SAT and ACT tests equally and do not have a preference of one test over the other ([*source*](https://www.princetonreview.com/college/sat-act)). Typically, the popularity of a test varies depending on the state and area in the country due to various reasons, which results in one test being more dominant than the other in some states.
#
# In 2016, the College Board redesigned and released the new SAT test, changing the content, format and scoring ([*source*](https://sat.ivyglobal.com/new-vs-old)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](../data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](../data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](../data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](../data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](../data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](../data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](../data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](../data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](../data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](../data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# Datasets used:
# * act_2017.csv (Participation rate and composite score)
# * act_2018.csv (Participation rate and composite score)
# * act_2019.csv (Participation rate and composite score)
# * sat_2017.csv (Participation rate and total score)
# * sat_2018.csv (Participation rate and total score)
# * sat_2019.csv (Participation rate and total score)

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Popularity of a test over the other in different states can be due to some states mandating one of the tests as part of their state testing program ([*source*](https://www.ontocollege.com/do-colleges-prefer-act-or-sat/)).
#
# States that implement mandatory testing for either SAT or ACT signs a contract with the organisation administrating the test. The state would then implement this mandatory testing for the years indicated in the contract ([*SAT contract example*](https://www.michigan.gov/documents/micontractconnect/5500079_485075_7.pdf)). Once the contract is up, the state may choose to renew the contract (the current test will continue to be mandatory) or sign with another organisation (making the other test the mandatory test instead).
#
# These ACT and SAT tests that the students take is not free and may quickly add up to a big sum, especially if the student intends to apply to many different colleges. This is because in addition to registration fees, there are other additional add-ons depending on what the student requires. One example is that the score report, which is required for submission to the colleges that the student is applying for, is charged per additional report after the 4 initial free reports ([*SAT Fees*](https://blog.prepscholar.com/sat-full-fees-and-registration-whats-the-total-cost-of-the-sat)).

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#function to calculate the average of input values
def calculate_mean(values_list):
    
    #variable to hold the sum of all values in the values_list
    total = 0
    
    #loop through values_list to get sum of all values
    for value in values_list:
        total += value
    
    #return the mean, which is sum divided by number of values in values_list
    return total/len(values_list)

#testing the function using a list of numbers
calculate_mean([1, 2, 3, 4, 5, 6])
# Out:
# 3.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
#function to calculate standard deviation
def calculate_std_dev(values_list):
    
    #call previously defined function to calculate the mean of list of values and assign to variable "mean"
    mean = calculate_mean(values_list)
    
    #calculate one component of the standard deviation: the sum of all (xi - u)^2
    #separated out as this component needs to loop through values_list
    #variable "std_dev_sum_component" created to hold this component's summed value
    std_dev_sum_component = 0
    for value in values_list:
        std_dev_sum_component += ((value - mean) ** 2)
    
    #return the standard deviation, calculated by square root of (1/number of values)*std_dev_sum_component
    return ((1 / (len(values_list)-1)) * std_dev_sum_component) ** .5

#testing the function using a list of numbers
calculate_std_dev([1, 2, 3])
# Out:
# 1.0

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
#define function to clean data, changing number percentage to decimal approx.
def percent_to_decimal(string):
    
    if (type(string) == str) and '%' in string:
        #use replace to remove the'%' in the string, then recast to float and divide by 100
        return float(string.replace('%', '')) / 100
    else:
        return string #return back in original form, to do further checks on the data
    
percent_to_decimal('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
#importing libraries to be used
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#loading all datasets used
act_17 = pd.read_csv('../data/act_2017.csv')
act_18 = pd.read_csv('../data/act_2018.csv')
act_19 = pd.read_csv('../data/act_2019.csv')
sat_17 = pd.read_csv('../data/sat_2017.csv')
sat_18 = pd.read_csv('../data/sat_2018.csv')
sat_19 = pd.read_csv('../data/sat_2019.csv')

#display first 5 rows in dataframes
print('ACT 2017\n', act_17.head())
print('\nACT 2018\n', act_18.head())
print('\nACT 2019\n', act_19.head())
print('\nSAT 2017\n', sat_17.head())
print('\nSAT 2018\n', sat_18.head())
print('\nSAT 2019\n', sat_19.head())
# Out:
# ACT 2017
#        State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4
#
# ACT 2018
#          State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
#
# ACT 2019
#          State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6
#
# SAT 2017
# ...

# %%
#check dataframes for missing values using .isnull()
#display total number of missing values with .sum()

print('ACT 2017\n', act_17.isnull().sum())
print('\nACT 2018\n', act_18.isnull().sum())
print('\nACT 2019\n', act_19.isnull().sum())
print('\nSAT 2017\n', sat_17.isnull().sum())
print('\nSAT 2018\n', sat_18.isnull().sum())
print('\nSAT 2019\n', sat_19.isnull().sum())
# Out:
# ACT 2017
#  State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64
#
# ACT 2018
#  State            0
# Participation    0
# Composite        0
# dtype: int64
#
# ACT 2019
#  State            0
# Participation    0
# Composite        0
# dtype: int64
#
# SAT 2017
#  State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
#
# SAT 2018
#  State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
#
# SAT 2019
#  State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
#check and display dataframes basic information using info() function
#describe() function (for min and max values)

print('ACT 2017')
act_17.info()
print('\n', act_17.describe())

print('\n------------------------\nACT 2018 Info')
act_18.info()
print('\n', act_18.describe())

print('\n------------------------\nACT 2019 Info')
act_19.info()
print('\n', act_19.describe())

print('\n------------------------\nSAT 2017 Info')
sat_17.info()
print('\n', sat_17.describe())

print('\n------------------------\nSAT 2018 Info')
sat_18.info()
print('\n', sat_18.describe())

print('\n------------------------\nSAT 2019 Info')
sat_19.info()
print('\n', sat_19.describe())
# Out:
# ACT 2017
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB
#
#           English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# ...

# %%
#displaying data types of each column in dataframes
print('ACT 2017\n', act_17.dtypes)
print('\nACT 2018\n', act_18.dtypes)
print('\nACT 2019\n', act_19.dtypes)
print('\nSAT 2017\n', sat_17.dtypes)
print('\nSAT 2018\n', sat_18.dtypes)
print('\nSAT 2019\n', sat_19.dtypes)
# Out:
# ACT 2017
#  State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object
#
# ACT 2018
#  State             object
# Participation     object
# Composite        float64
# dtype: object
#
# ACT 2019
#  State             object
# Participation     object
# Composite        float64
# dtype: object
#
# SAT 2017
#  State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
# SAT 2018
#  State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
# SAT 2019
# ...

# %%
#display ACT 2017 dataframe 'Composite' column values to check
#data type for ACT 2017['Composite'] should be float
np.unique(act_17['Composite'])
# Out:
# array(['17.8', '18.6', '18.7', '19.0', '19.1', '19.2', '19.4', '19.5',
#        '19.7', '19.8', '20.0', '20.2x', '20.3', '20.4', '20.5', '20.7',
#        '20.8', '21.0', '21.4', '21.5', '21.7', '21.8', '21.9', '22.0',
#        '22.3', '22.6', '22.8', '23.6', '23.7', '23.8', '23.9', '24.0',
#        '24.1', '24.2', '24.3', '25.2', '25.4', '25.5'], dtype=object)

# %%
#display ACT 2017, 2018, 2019 and SAT 2017, 2018, 2019 dataframe 'Participation' column values to check
#will change to float later, currently all values should have percentage sign (seen from csv file directly)

print('ACT 2017\n', np.unique(act_17['Participation']))
print('\nACT 2018\n', np.unique(act_18['Participation']))
print('\nACT 2019\n', np.unique(act_19['Participation']))
print('\nSAT 2017\n', np.unique(sat_17['Participation']))
print('\nSAT 2018\n', np.unique(sat_18['Participation']))
print('\nSAT 2019\n', np.unique(sat_19['Participation Rate']))
# Out:
# ACT 2017
#  [' 60%' '100%' '18%' '21%' '23%' '28%' '29%' '31%' '32%' '34%' '35%' '38%'
#  '40%' '45%' '55%' '62%' '65%' '66%' '67%' '69%' '73%' '75%' '8%' '80%'
#  '84%' '90%' '93%' '98%']
#
# ACT 2018
#  ['100%' '15%' '16%' '17%' '20%' '22%' '24%' '25%' '26%' '27%' '30%' '31%'
#  '32%' '33%' '36%' '42%' '43%' '45%' '53%' '65%' '66%' '67%' '68%' '7%'
#  '71%' '77%' '89%' '98%' '99%']
#
# ACT 2019
#  ['100%' '12%' '13%' '14%' '17%' '19%' '20%' '21%' '22%' '23%' '24%' '25%'
#  '27%' '28%' '29%' '31%' '32%' '35%' '38%' '39%' '42%' '49%' '52%' '54%'
#  '6%' '63%' '66%' '72%' '73%' '75%' '78%' '80%' '82%' '95%' '96%']
#
# SAT 2017
#  ['10%' '100%' '11%' '12%' '14%' '2%' '26%' '3%' '30%' '38%' '4%' '43%'
#  '49%' '5%' '50%' '53%' '55%' '60%' '61%' '62%' '63%' '64%' '65%' '67%'
#  '69%' '7%' '70%' '71%' '76%' '83%' '9%' '93%' '95%' '96%']
#
# SAT 2018
#  ['10%' '100%' '16%' '18%' '2%' '23%' '28%' '29%' '3%' '4%' '43%' '48%'
# ...

# %%
#fix individual values that prevents changing column to other data type
#act_17['Composite'] has value '20.2x' --> remove the extra 'x'
act_17['Composite'] = act_17['Composite'].map(lambda act_17_cell: act_17_cell.replace('x', ''))

np.unique(act_17['Composite'])
# Out:
# array(['17.8', '18.6', '18.7', '19.0', '19.1', '19.2', '19.4', '19.5',
#        '19.7', '19.8', '20.0', '20.2', '20.3', '20.4', '20.5', '20.7',
#        '20.8', '21.0', '21.4', '21.5', '21.7', '21.8', '21.9', '22.0',
#        '22.3', '22.6', '22.8', '23.6', '23.7', '23.8', '23.9', '24.0',
#        '24.1', '24.2', '24.3', '25.2', '25.4', '25.5'], dtype=object)

# %%
#fix individual values that prevents changing column to other data type
#sat_19['Participation Rate'] has value '-' --> change to 0.0% for percent_to_decimal() function later
sat_19['Participation Rate'] = sat_19['Participation Rate'].map(lambda sat_19_cell: sat_19_cell.replace('—', '0.0%'))

np.unique(sat_19['Participation Rate'])
# Out:
# array(['0.0%', '100%', '18%', '19%', '2%', '20%', '22%', '3%', '31%',
#        '4%', '41%', '5%', '51%', '54%', '6%', '63%', '66%', '68%', '7%',
#        '70%', '71%', '79%', '81%', '82%', '9%', '94%', '95%', '99%'],
#       dtype=object)

# %%
#change all incorrect data types to the correct data type
#act_2017['Composite'] to change to float
act_17['Composite'] = act_17['Composite'].astype(float)

act_17.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
#clean participation rates with precentages to decimals for all dataframes, using .apply() method
act_17['Participation'] = act_17['Participation'].apply(percent_to_decimal)
act_18['Participation'] = act_18['Participation'].apply(percent_to_decimal)
act_19['Participation'] = act_19['Participation'].apply(percent_to_decimal)
sat_17['Participation'] = sat_17['Participation'].apply(percent_to_decimal)
sat_18['Participation'] = sat_18['Participation'].apply(percent_to_decimal)
sat_19['Participation Rate'] = sat_19['Participation Rate'].apply(percent_to_decimal)

print(act_17['Participation'].dtypes)
print(act_18['Participation'].dtypes)
print(act_19['Participation'].dtypes)
print(sat_17['Participation'].dtypes)
print(sat_18['Participation'].dtypes)
print(sat_19['Participation Rate'].dtypes)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64

# %%
#drop all unnecessary columns

#ACT 2017 --> (English, Math, Reading, Science)
act_17.drop(columns=['English', 'Math', 'Reading', 'Science'], axis=1, inplace=True)
#print(act_17.head())

#SAT 2017 --> (Evidence-Based Reading and Writing, Math)
sat_17.drop(columns=['Evidence-Based Reading and Writing', 'Math'], axis=1, inplace=True)
#print(sat_17.head())

#SAT 2018 --> (Evidence-Based Reading and Writing, Math)
sat_18.drop(columns=['Evidence-Based Reading and Writing', 'Math'], axis=1, inplace=True)
#print(sat_18.head())

#SAT 2019 --> (Evidence-Based Reading and Writing, Math)
sat_19.drop(columns=['EBRW', 'Math'], axis=1, inplace=True)
#print(sat_19.head())

# %%
#check on all dataframes ran above to ensure the columns are dropped
print('ACT 2017\n', act_17.head())
print('\nSAT 2017\n', sat_17.head())
print('\nSAT 2018\n', sat_18.head())
print('\nSAT 2019\n', sat_19.head())
# Out:
# ACT 2017
#        State  Participation  Composite
# 0  National           0.60       21.0
# 1   Alabama           1.00       19.2
# 2    Alaska           0.65       19.8
# 3   Arizona           0.62       19.7
# 4  Arkansas           1.00       19.4
#
# SAT 2017
#          State  Participation  Total
# 0     Alabama           0.05   1165
# 1      Alaska           0.38   1080
# 2     Arizona           0.30   1116
# 3    Arkansas           0.03   1208
# 4  California           0.53   1055
#
# SAT 2018
#          State  Participation  Total
# 0     Alabama           0.06   1166
# 1      Alaska           0.43   1106
# 2     Arizona           0.29   1149
# 3    Arkansas           0.05   1169
# 4  California           0.60   1076
#
# SAT 2019
#          State  Participation Rate  Total
# 0     Alabama                0.07   1143
# 1      Alaska                0.41   1097
# 2     Arizona                0.31   1134
# 3    Arkansas                0.06   1141
# ...

# %%
#renaming columns --> all lowercase and no spaces, unique and informative

#ACT 2017 renaming columns
act_17.columns = act_17.columns.str.lower()
act_17.rename(columns={
    'participation': 'act_participation_2017',
    'composite': 'act_composite_2017'
}, inplace=True)

#ACT 2018 renaming columns
act_18.columns = act_18.columns.str.lower()
act_18.rename(columns={
    'participation': 'act_participation_2018',
    'composite': 'act_composite_2018'
}, inplace=True)

#ACT 2019 renaming columns
act_19.columns = act_19.columns.str.lower()
act_19.rename(columns={
    'participation': 'act_participation_2019',
    'composite': 'act_composite_2019'
}, inplace=True)

#SAT 2017 renaming columns
sat_17.columns = sat_17.columns.str.lower()
sat_17.rename(columns={
    'participation': 'sat_participation_2017',
    'total': 'sat_total_2017'
}, inplace=True)

#SAT 2018 renaming columns
sat_18.columns = sat_18.columns.str.lower()
sat_18.rename(columns={
    'participation': 'sat_participation_2018',
    'total': 'sat_total_2018'
}, inplace=True)

#SAT 2019 renaming columns
sat_19.columns = sat_19.columns.str.lower()
sat_19.rename(columns={
    'participation rate': 'sat_participation_2019',
    'total': 'sat_total_2019'
}, inplace=True)

# %%
#check to see if columns are renamed properly
print('ACT 2017\n', act_17.head())
print('\nACT 2018\n', act_18.head())
print('\nACT 2019\n', act_19.head())
print('\nSAT 2017\n', sat_17.head())
print('\nSAT 2018\n', sat_18.head())
print('\nSAT 2019\n', sat_19.head())
# Out:
# ACT 2017
#        state  act_participation_2017  act_composite_2017
# 0  National                    0.60                21.0
# 1   Alabama                    1.00                19.2
# 2    Alaska                    0.65                19.8
# 3   Arizona                    0.62                19.7
# 4  Arkansas                    1.00                19.4
#
# ACT 2018
#          state  act_participation_2018  act_composite_2018
# 0     Alabama                    1.00                19.1
# 1      Alaska                    0.33                20.8
# 2     Arizona                    0.66                19.2
# 3    Arkansas                    1.00                19.4
# 4  California                    0.27                22.7
#
# ACT 2019
#          state  act_participation_2019  act_composite_2019
# 0     Alabama                    1.00                18.9
# 1      Alaska                    0.38                20.1
# 2     Arizona                    0.73                19.0
# ...

# %%
#sort dataframes according to States
act_17 = act_17.sort_values('state')
act_18 = act_18.sort_values('state')
act_19 = act_19.sort_values('state')
sat_17 = sat_17.sort_values('state')
sat_18 = sat_18.sort_values('state')
sat_19 = sat_19.sort_values('state')

# %%
#check to see if sorted properly

print('ACT 2017\n', act_17.head(10))
print('\nACT 2018\n', act_18.head(10))
print('\nACT 2019\n', act_19.head(10))
print('\nSAT 2017\n', sat_17.head(10))
print('\nSAT 2018\n', sat_18.head(10))
print('\nSAT 2019\n', sat_19.head(10))
# Out:
# ACT 2017
#                     state  act_participation_2017  act_composite_2017
# 1                Alabama                    1.00                19.2
# 2                 Alaska                    0.65                19.8
# 3                Arizona                    0.62                19.7
# 4               Arkansas                    1.00                19.4
# 5             California                    0.31                22.8
# 6               Colorado                    1.00                20.8
# 7            Connecticut                    0.31                25.2
# 8               Delaware                    0.18                24.1
# 9   District of Columbia                    0.32                24.2
# 10               Florida                    0.73                19.8
#
# ACT 2018
#                    state  act_participation_2018  act_composite_2018
# 0               Alabama                    1.00                19.1
# ...

# %%
#change all states values to lower case
act_17['state'] = act_17['state'].apply(lambda state: state.lower())
act_18['state'] = act_18['state'].apply(lambda state: state.lower())
act_19['state'] = act_19['state'].apply(lambda state: state.lower())
sat_17['state'] = sat_17['state'].apply(lambda state: state.lower())
sat_18['state'] = sat_18['state'].apply(lambda state: state.lower())
sat_19['state'] = sat_19['state'].apply(lambda state: state.lower())

print('ACT 2017\n', act_17.head())
print('\nACT 2018\n', act_18.head())
print('\nACT 2019\n', act_19.head())
print('\nSAT 2017\n', sat_17.head())
print('\nSAT 2018\n', sat_18.head())
print('\nSAT 2019\n', sat_19.head())
# Out:
# ACT 2017
#          state  act_participation_2017  act_composite_2017
# 1     alabama                    1.00                19.2
# 2      alaska                    0.65                19.8
# 3     arizona                    0.62                19.7
# 4    arkansas                    1.00                19.4
# 5  california                    0.31                22.8
#
# ACT 2018
#          state  act_participation_2018  act_composite_2018
# 0     alabama                    1.00                19.1
# 1      alaska                    0.33                20.8
# 2     arizona                    0.66                19.2
# 3    arkansas                    1.00                19.4
# 4  california                    0.27                22.7
#
# ACT 2019
#          state  act_participation_2019  act_composite_2019
# 0     alabama                    1.00                18.9
# 1      alaska                    0.38                20.1
# 2     arizona                    0.73                19.0
# ...

# %%
#merge data frames together according to states
#clean up data so that merged dataframe has values for all cells

#outer merge act_17 and act_18, check for rows that need to clean up
act_17_18 = pd.merge(act_17, act_18, on='state', how='outer', indicator='indicators')
#act_17_18

#drop duplicates and keep first occurence --> ensure all states only appear once
act_17_18 = act_17_18.drop_duplicates(subset=['state', 'act_composite_2018'], keep='first')

#drop columns that do not appear in both dataframes (indicators column != 'both') and reset index
act_17_18 = act_17_18.drop(act_17_18[act_17_18.indicators != 'both'].index).reset_index(drop=True)
act_17_18
# Out:
#                    state  act_participation_2017  act_composite_2017  \
# 0                alabama                    1.00                19.2
# 1                 alaska                    0.65                19.8
# 2                arizona                    0.62                19.7
# 3               arkansas                    1.00                19.4
# 4             california                    0.31                22.8
# 5               colorado                    1.00                20.8
# 6            connecticut                    0.31                25.2
# 7               delaware                    0.18                24.1
# 8   district of columbia                    0.32                24.2
# 9                florida                    0.73                19.8
# 10               georgia                    0.55                21.4
# 11                hawaii                    0.90                19.0
# 12                 idaho                    0.38                22.3
# ...

# %%
#drop 'indicators' column as it is no longer necessary
act_17_18.drop(columns='indicators', axis=1, inplace=True)

#using act_17_18 dataframe as base, merge all other dataframes into it to save as on csv file later on
act_sat_17_18_19 = pd.merge(act_17_18, act_19, on='state', how='left')
act_sat_17_18_19 = pd.merge(act_sat_17_18_19, sat_17, on='state', how='left')
act_sat_17_18_19 = pd.merge(act_sat_17_18_19, sat_18, on='state', how='left')
act_sat_17_18_19 = pd.merge(act_sat_17_18_19, sat_19, on='state', how='left')

#check if there are any NULL values that was introduced from the merging
print('\nAll Dataframes Combined into one\n', act_sat_17_18_19.isnull().sum())
# Out:
# All Dataframes Combined into one
#  state                     0
# act_participation_2017    0
# act_composite_2017        0
# act_participation_2018    0
# act_composite_2018        0
# act_participation_2019    0
# act_composite_2019        0
# sat_participation_2017    0
# sat_total_2017            0
# sat_participation_2018    0
# sat_total_2018            0
# sat_participation_2019    0
# sat_total_2019            0
# dtype: int64

# %%
#rearrange columns so that participation rate is all on the left and scores on the right
act_sat_17_18_19 = act_sat_17_18_19[[
    'state',
    'act_participation_2017', 
    'act_participation_2018', 
    'act_participation_2019', 
    'sat_participation_2017', 
    'sat_participation_2018', 
    'sat_participation_2019', 
    'act_composite_2017', 
    'act_composite_2018', 
    'act_composite_2019', 
    'sat_total_2017', 
    'sat_total_2018', 
    'sat_total_2019']]

act_sat_17_18_19.head()
# Out:
#         state  act_participation_2017  act_participation_2018  \
# 0     alabama                    1.00                    1.00
# 1      alaska                    0.65                    0.33
# 2     arizona                    0.62                    0.66
# 3    arkansas                    1.00                    1.00
# 4  california                    0.31                    0.27
#
#    act_participation_2019  sat_participation_2017  sat_participation_2018  \
# 0                    1.00                    0.05                    0.06
# 1                    0.38                    0.38                    0.43
# 2                    0.73                    0.30                    0.29
# 3                    1.00                    0.03                    0.05
# 4                    0.23                    0.53                    0.60
#
#    sat_participation_2019  act_composite_2017  act_composite_2018  \
# 0                    0.07                19.2                19.1
# ...

# %%
#add columns to show average of SAT and ACT data

act_sat_17_18_19['sat_avg_participation'] = act_sat_17_18_19.loc[:, 'sat_participation_2017': 'sat_participation_2019'].mean(axis=1).round(2)
act_sat_17_18_19['sat_avg_total'] = act_sat_17_18_19.loc[:, 'sat_total_2017': 'sat_total_2019'].mean(axis=1).round()
act_sat_17_18_19['act_avg_participation'] = act_sat_17_18_19.loc[:, 'act_participation_2017': 'act_participation_2019'].mean(axis=1).round(2)
act_sat_17_18_19['act_avg_composite'] = act_sat_17_18_19.loc[:, 'act_composite_2017': 'act_composite_2019'].mean(axis=1).round()

act_sat_17_18_19.head()
# Out:
#         state  act_participation_2017  act_participation_2018  \
# 0     alabama                    1.00                    1.00
# 1      alaska                    0.65                    0.33
# 2     arizona                    0.62                    0.66
# 3    arkansas                    1.00                    1.00
# 4  california                    0.31                    0.27
#
#    act_participation_2019  sat_participation_2017  sat_participation_2018  \
# 0                    1.00                    0.05                    0.06
# 1                    0.38                    0.38                    0.43
# 2                    0.73                    0.30                    0.29
# 3                    1.00                    0.03                    0.05
# 4                    0.23                    0.53                    0.60
#
#    sat_participation_2019  act_composite_2017  act_composite_2018  \
# 0                    0.07                19.2                19.1
# ...

# %%
#save dataframe as new csv files
act_sat_17_18_19.to_csv('../data/act-sat-17-18-19-cleaned.csv', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*string*|act_sat_17_18_19|The list of states in the country with ACT and SAT data|
# |**act_participation_2017**|*float*|act_sat_17_18_19|The percent of 2017 ACT participation rate in a state (units percent in decimal format to 2 decimal places, 0.64 means 64%)|
# |**act_participation_2018**|*float*|act_sat_17_18_19|The percent of 2018 ACT participation rate in a state (units percent in decimal format to 2 decimal places, 0.64 means 64%)|
# |**act_participation_2019**|*float*|act_sat_17_18_19|The percent of 2019 ACT participation rate in a state (units percent in decimal format to 2 decimal places, 0.64 means 64%)|
# |**sat_participation_2017**|*float*|act_sat_17_18_19|The percent of 2017 SAT participation rate in a state (units percent in decimal format to 2 decimal places, 0.64 means 64%)
# |**sat_participation_2018**|*float*|act_sat_17_18_19|The percent of 2018 SAT participation rate in a state (units percent in decimal format to 2 decimal places, 0.64 means 64%)|
# |**sat_participation_2019**|*float*|act_sat_17_18_19|The percent of 2019 SAT participation rate in a state (units percent in decimal format to 2 decimal places, 0.64 means 64%)|
# |**act_composite_2017**|*float*|act_sat_17_18_19|The value of 2017 ACT composite score (average score of all subjects) in a state (no units, to 1 decimal place)|
# |**act_composite_2018**|*float*|act_sat_17_18_19|The value of 2018 ACT composite score (average score of all subjects) in a state (no units, to 1 decimal place)|
# |**act_composite_2019**|*float*|act_sat_17_18_19|The value of 2019 ACT composite score (average score of all subjects) in a state (no units, to 1 decimal place)|
# |**sat_total_2017**|*integer*|act_sat_17_18_19|The value of 2017 SAT total score in a state (no units)|
# |**sat_total_2018**|*integer*|act_sat_17_18_19|The value of 2018 SAT total score in a state (no units)|
# |**sat_total_2019**|*integer*|act_sat_17_18_19|The value of 2019 SAT total score in a state (no units)|
# |**sat_avg_participation**|*float*|act_sat_17_18_19|The percent of mean SAT participation rate from 2017-2019 in a state (units percent in decimal format to 2 decimal places, 0.64 means 64%)|
# |**sat_avg_total**|*float*|act_sat_17_18_19|The mean value of 2019 SAT total score from 2017-2019 in a state (no units, to 1 decimal place)|
# |**act_avg_participation**|*float*|act_sat_17_18_19|The percent of mean ACT participation rate from 2017-2019 in a state (units percent in decimal format to 2 decimal places, 0.64 means 64%)|
# |**act_avg_composite**|*float*|act_sat_17_18_19|The value of mean ACT composite score (average score of all subjects) from 2017-2019 in a state (no units, to 1 decimal place)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#loading cleaned dataset from csv created
cleaned_data = pd.read_csv('../data/act-sat-17-18-19-cleaned.csv')

# %%
#display summary statistics using .describe()
print('Clean ACT and SAT 2017-2019\n', cleaned_data.describe())
# Out:
# Clean ACT and SAT 2017-2019
#         act_participation_2017  act_participation_2018  act_participation_2019  \
# count               51.000000               51.000000               51.000000
# mean                 0.652549                0.617255                0.586667
# std                  0.321408                0.340371                0.345159
# min                  0.080000                0.070000                0.060000
# 25%                  0.310000                0.285000                0.245000
# 50%                  0.690000                0.660000                0.540000
# 75%                  1.000000                1.000000                1.000000
# max                  1.000000                1.000000                1.000000
#
#        sat_participation_2017  sat_participation_2018  sat_participation_2019  \
# count               51.000000               51.000000               51.000000
# mean                 0.398039                0.457451                0.490588
# ...

# %% [markdown]
# From the information above, an estimation of the average scores are:
# * SAT average score = 1100
# * ACT average score = 21
#
# These values will be used to do data trend investigation.

# %%
#dictionary comprehension to find standard deviation for all columns (13 columns in total --> take from index 1 (inclusive) to 13(exclusive) )
sd = {cleaned_data.columns[col_num]:calculate_std_dev(cleaned_data.loc[:, cleaned_data.columns[col_num]]) 
      for col_num in range(1, 17)}

sd
# Out:
# {'act_participation_2017': 0.32140842015886834,
#  'act_participation_2018': 0.34037084734960815,
#  'act_participation_2019': 0.34515890060473114,
#  'sat_participation_2017': 0.35276632270013036,
#  'sat_participation_2018': 0.37314256330391965,
#  'sat_participation_2019': 0.38747599546142664,
#  'act_composite_2017': 2.020694891154341,
#  'act_composite_2018': 2.111583366510896,
#  'act_composite_2019': 2.1945225931315235,
#  'sat_total_2017': 92.49481172519046,
#  'sat_total_2018': 94.15508275097599,
#  'sat_total_2019': 97.1979100880785,
#  'sat_avg_participation': 0.35727443178576773,
#  'sat_avg_total': 90.90804662501814,
#  'act_avg_participation': 0.3288487345210233,
#  'act_avg_composite': 2.0712788509593234}

# %%
cleaned_data.head()
# Out:
#         state  act_participation_2017  act_participation_2018  \
# 0     alabama                    1.00                    1.00
# 1      alaska                    0.65                    0.33
# 2     arizona                    0.62                    0.66
# 3    arkansas                    1.00                    1.00
# 4  california                    0.31                    0.27
#
#    act_participation_2019  sat_participation_2017  sat_participation_2018  \
# 0                    1.00                    0.05                    0.06
# 1                    0.38                    0.38                    0.43
# 2                    0.73                    0.30                    0.29
# 3                    1.00                    0.03                    0.05
# 4                    0.23                    0.53                    0.60
#
#    sat_participation_2019  act_composite_2017  act_composite_2018  \
# 0                    0.07                19.2                19.1
# ...

# %%
#using boolean filtering on mulitple columns to find States with at least 80% ACT participation rate for years 2017-2019 consistently
act_min_80percent = cleaned_data[
    (cleaned_data['act_participation_2017'] >= 0.8) & 
    (cleaned_data['act_participation_2018'] >= 0.8) & 
    (cleaned_data['act_participation_2019'] >= 0.8)
]

#drop unnecessary columns and leave only ACT participation and composite score
act_min_80percent = act_min_80percent.drop(columns=[
    'sat_participation_2017', 
    'sat_participation_2018', 
    'sat_participation_2019', 
    'sat_total_2017', 
    'sat_total_2018', 
    'sat_total_2019', 
    'sat_avg_participation', 
    'sat_avg_total', 
    'act_avg_participation', 
    'act_avg_composite'
])
act_min_80percent
# Out:
#              state  act_participation_2017  act_participation_2018  \
# 0          alabama                    1.00                    1.00
# 3         arkansas                    1.00                    1.00
# 11          hawaii                    0.90                    0.89
# 17        kentucky                    1.00                    1.00
# 18       louisiana                    1.00                    1.00
# 23       minnesota                    1.00                    0.99
# 24     mississippi                    1.00                    1.00
# 25        missouri                    1.00                    1.00
# 26         montana                    1.00                    1.00
# 27        nebraska                    0.84                    1.00
# 28          nevada                    1.00                    1.00
# 33  north carolina                    1.00                    1.00
# 34    north dakota                    0.98                    0.98
# ...

# %% [markdown]
# For states with consistently high ACT participation rate (at least 80% participation rate) in all 3 years of 2017-2019, there seems to be a trend where the state's composite scores are generally below the found average of 21 points.

# %%
#use boolean filter to confirm the trend on dataframe act_min_80percent (filtered ACT participation rate to at least 80% for 2017-2019)
#trend seems to be that for states with participation rate >= 80%, ACT scores < 21
print('ACT scores for 2017 is < 21\n', act_min_80percent['act_composite_2017'] < 21)
print('\nACT scores for 2018 is < 21\n', act_min_80percent['act_composite_2018'] < 21)
print('\nACT scores for 2019 is < 21\n', act_min_80percent['act_composite_2019'] < 21)
# Out:
# ACT scores for 2017 is < 21
#  0      True
# 3      True
# 11     True
# 17     True
# 18     True
# 23    False
# 24     True
# 25     True
# 26     True
# 27    False
# 28     True
# 33     True
# 34     True
# 36     True
# 42     True
# 44     True
# 49     True
# 50     True
# Name: act_composite_2017, dtype: bool
#
# ACT scores for 2018 is < 21
#  0      True
# 3      True
# 11     True
# 17     True
# 18     True
# 23    False
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 33     True
# 34     True
# 36     True
# 42     True
# 44     True
# 49     True
# 50     True
# Name: act_composite_2018, dtype: bool
#
# ACT scores for 2019 is < 21
#  0      True
# 3      True
# 11     True
# 17     True
# 18     True
# 23    False
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 33     True
# 34     True
# 36     True
# 42     True
# 44     True
# 49     True
# 50     True
# Name: act_composite_2019, dtype: bool

# %% [markdown]
# Using boolean filter on the dataframe containing states with minimum 80% ACT participation rate across years 2017-2019, it can be confirmed that majority of these states' ACT composite scores fall below the found average of 21 points.

# %%
#using boolean filtering on mulitple columns to find States with lower than 30% ACT participation rate for years 2017-2019 consistently
act_max_30percent = cleaned_data[
    (cleaned_data['act_participation_2017'] < 0.3) & 
    (cleaned_data['act_participation_2018'] < 0.3) & 
    (cleaned_data['act_participation_2019'] < 0.3)
]

#drop unnecessary columns and leave only ACT participation and composite score
act_max_30percent = act_max_30percent.drop(columns=[
    'sat_participation_2017', 
    'sat_participation_2018', 
    'sat_participation_2019', 
    'sat_total_2017', 
    'sat_total_2018', 
    'sat_total_2019', 
    'sat_avg_participation', 
    'sat_avg_total', 
    'act_avg_participation', 
    'act_avg_composite'
])
act_max_30percent
# Out:
#             state  act_participation_2017  act_participation_2018  \
# 7        delaware                    0.18                    0.17
# 19          maine                    0.08                    0.07
# 21  massachusetts                    0.29                    0.25
# 22       michigan                    0.29                    0.22
# 29  new hampshire                    0.18                    0.16
# 38   pennsylvania                    0.23                    0.20
# 39   rhode island                    0.21                    0.15
# 45        vermont                    0.29                    0.24
# 46       virginia                    0.29                    0.24
# 47     washington                    0.29                    0.24
#
#     act_participation_2019  act_composite_2017  act_composite_2018  \
# 7                     0.13                24.1                23.8
# 19                    0.06                24.3                24.0
# ...

# %% [markdown]
# For states with consistently low ACT participation rate (below 20% participation rate) in all 3 years of 2017-2019, there seems to be a trend where the state's composite scores are generally above the found average of 21 points.

# %%
#use boolean filter to confirm the trend on dataframe act_max_30percent (filtered ACT participation rate to below 30% for 2017-2019)
#trend seems to be that for states with participation rate < 30%, ACT scores > 21
print('ACT scores for 2017 is > the found average of 21\n', act_max_30percent['act_composite_2017'] > 21)
print('\nACT scores for 2018 is > the found average of 21\n', act_max_30percent['act_composite_2018'] > 21)
print('\nACT scores for 2019 is > the found average of 21\n', act_max_30percent['act_composite_2019'] > 21)
# Out:
# ACT scores for 2017 is > the found average of 21
#  7     True
# 19    True
# 21    True
# 22    True
# 29    True
# 38    True
# 39    True
# 45    True
# 46    True
# 47    True
# Name: act_composite_2017, dtype: bool
#
# ACT scores for 2018 is > the found average of 21
#  7     True
# 19    True
# 21    True
# 22    True
# 29    True
# 38    True
# 39    True
# 45    True
# 46    True
# 47    True
# Name: act_composite_2018, dtype: bool
#
# ACT scores for 2019 is > the found average of 21
#  7     True
# 19    True
# 21    True
# 22    True
# 29    True
# 38    True
# 39    True
# 45    True
# 46    True
# 47    True
# Name: act_composite_2019, dtype: bool

# %% [markdown]
# Using boolean filter on the dataframe containing states with ACT participation rate lower than 30% across years 2017-2019, it can be confirmed that majority of these states' ACT composite scores are above the found average of 21 points.

# %% [markdown]
# ACT data comparison summary:
# * participation rate >= 80% sees the states scoring below the average of 21 points
# * participation rate < 30% sees the states scoring above the average of 21 points
#
# The general trend with ACT participation rate vs ACT composite scores seem to show that states with higher ACT participation rate tend to score lower, while states with higher ACT participation rate tends to score higher.

# %%
#use sorting by column to find states with at least 80% SAT participation rate for years 2017-2019 consistently
sat_min_80percent = cleaned_data.loc[
    (cleaned_data['sat_participation_2017'] >= 0.8) & 
    (cleaned_data['sat_participation_2018'] >= 0.8) & 
    (cleaned_data['sat_participation_2019'] >= 0.8)
]

#drop unnecessary columns and leave only SAT participation rate and total scores
sat_min_80percent = sat_min_80percent.drop(columns=[
    'act_participation_2017', 
    'act_participation_2018', 
    'act_participation_2019', 
    'act_composite_2017', 
    'act_composite_2018', 
    'act_composite_2019', 
    'sat_avg_participation', 
    'sat_avg_total', 
    'act_avg_participation', 
    'act_avg_composite'
])

#use column sorting to better show the trend on dataframe sat_min_80percent (filtered SAT participation rate to at least 80% for 2017-2019)
#trend seems to be that for states with participation rate >= 80%, SAT scores < the found average of 1100
sat_min_80percent = sat_min_80percent.sort_values(['sat_total_2017', 'sat_total_2018', 'sat_total_2019'], ascending=[False, False, False])
sat_min_80percent
# Out:
#                    state  sat_participation_2017  sat_participation_2018  \
# 29         new hampshire                    0.96                    0.96
# 6            connecticut                    1.00                    1.00
# 19                 maine                    0.95                    0.99
# 22              michigan                    1.00                    1.00
# 12                 idaho                    0.93                    1.00
# 7               delaware                    1.00                    1.00
# 8   district of columbia                    1.00                    0.92
#
#     sat_participation_2019  sat_total_2017  sat_total_2018  sat_total_2019
# 29                    0.95            1052            1063            1059
# 6                     1.00            1041            1053            1046
# 19                    0.99            1012            1013            1013
# 22                    1.00            1005            1011            1003
# ...

# %% [markdown]
# For states with consistently high SAT participation rate (at least 80% participation rate) in all 3 years of 2017-2019, sorting the dataframe by descending SAT scores show clearly that these states' total SAT scores are generally below the found average of 1100 points.

# %%
#use sorting by column to find states with lower than 20% SAT participation rate for years 2017-2019 consistently
sat_max_20percent = cleaned_data.loc[
    (cleaned_data['sat_participation_2017'] < 0.2) & 
    (cleaned_data['sat_participation_2018'] < 0.2) & 
    (cleaned_data['sat_participation_2019'] < 0.2)
]

#drop unnecessary columns and leave only SAT participation rate and total scores
sat_max_20percent = sat_max_20percent.drop(columns=[
    'act_participation_2017', 
    'act_participation_2018', 
    'act_participation_2019', 
    'act_composite_2017', 
    'act_composite_2018', 
    'act_composite_2019', 
    'sat_avg_participation', 
    'sat_avg_total', 
    'act_avg_participation', 
    'act_avg_composite'
])

#use column sorting to better show the trend on dataframe sat_max_20percent (filtered SAT participation rate to below 20% for 2017-2019)
#trend seems to be that for states with participation rate < 20%, SAT scores are generally > the found average of 1100
sat_max_20percent = sat_max_20percent.sort_values(['sat_total_2017', 'sat_total_2018', 'sat_total_2019'], ascending=[False, False, False])
sat_max_20percent
# Out:
#            state  sat_participation_2017  sat_participation_2018  \
# 23     minnesota                    0.03                    0.04
# 49     wisconsin                    0.03                    0.03
# 15          iowa                    0.02                    0.03
# 25      missouri                    0.03                    0.04
# 16        kansas                    0.04                    0.04
# 34  north dakota                    0.02                    0.02
# 27      nebraska                    0.03                    0.03
# 17      kentucky                    0.04                    0.04
# 24   mississippi                    0.02                    0.03
# 44          utah                    0.03                    0.04
# 50       wyoming                    0.03                    0.03
# 42     tennessee                    0.05                    0.06
# 41  south dakota                    0.03                    0.03
# ...

# %% [markdown]
# For states with consistently low SAT participation rate (below 20% participation rate) in all 3 years of 2017-2019, sorting the dataframe by descending SAT scores show clearly that these states' total SAT scores are generally above the found average of 1100 points.

# %% [markdown]
# SAT data comparison summary:
# * participation rate >= 80% sees the states scoring below the average of 1100 points
# * participation rate < 20% sees the states scoring above the average of 1100 points
#
# The general trend with SAT participation rate vs SAT total scores seem to show that states with higher SAT participation rate tend to score lower, while states with higher SAT participation rate tends to score higher.
#
# This trend seems to be similar to the ACT trend found earlier where states with higher ACT participation rate tends to score lower and vice versa.
#
# In general, higher participation rate in either of the tests seem to result in lower score points.

# %% [markdown]
# For further investigations and better understanding, there will be a need to look for a relationship between the SAT data and ACT data.
#
# To start off, we will look for a relationship between high SAT participation rate (which also means lower SAT scoring) and the resulting ACT data.

# %%
#see if there is a relation between high SAT participation rate/low SAT score with ACT participation rate and ACT scores

#drop all unecessary columns, leave only the SAT and ACT averages
sat_act_average_compare = cleaned_data.filter([
    'state',
    'sat_avg_participation', 
    'sat_avg_total', 
    'act_avg_participation', 
    'act_avg_composite'
], axis=1)

sat_act_average_compare.head(10)
# Out:
#                   state  sat_avg_participation  sat_avg_total  \
# 0               alabama                   0.06         1158.0
# 1                alaska                   0.41         1094.0
# 2               arizona                   0.30         1133.0
# 3              arkansas                   0.05         1173.0
# 4            california                   0.59         1065.0
# 5              colorado                   0.70         1083.0
# 6           connecticut                   1.00         1047.0
# 7              delaware                   1.00          993.0
# 8  district of columbia                   0.95          967.0
# 9               florida                   0.80         1038.0
#
#    act_avg_participation  act_avg_composite
# 0                   1.00               19.0
# 1                   0.45               20.0
# 2                   0.67               19.0
# 3                   1.00               19.0
# 4                   0.27               23.0
# ...

# %%
#sort dataframe to contain states with high SAT participation rate of at least 80%
high_sat_compare = sat_act_average_compare.loc[sat_act_average_compare['sat_avg_participation'] >= 0.8]

high_sat_compare = high_sat_compare.sort_values('sat_avg_participation', ascending=False).head(5)

high_sat_compare
# Out:
#           state  sat_avg_participation  sat_avg_total  act_avg_participation  \
# 6   connecticut                   1.00         1047.0                   0.26
# 7      delaware                   1.00          993.0                   0.16
# 22     michigan                   1.00         1006.0                   0.23
# 12        idaho                   0.98         1000.0                   0.35
# 19        maine                   0.98         1013.0                   0.07
#
#     act_avg_composite
# 6                25.0
# 7                24.0
# 22               24.0
# 12               22.0
# 19               24.0

# %% [markdown]
# From the table above, the trend seems to be:
# * States with high SAT participation generally have relatively low ACT participation in comparison
# * States with high SAT participation seems to generally score high on ACT  (ACT mostly above the found average of 21 composite points) despite low SAT score (SAT below the found average of 1100 total points)
#
# In other words, states with high SAT participation will generally have low ACT participation, but these states tend to score below average for SAT while scoring above average for ACT.
#
# This may be due to some states making it mandatory for their students to take SAT, resulting in high SAT participation rate.
#
# In these states with mandatory SAT testing, it is likely that only students who personally prefers to take the optional ACT test and are fully prepared for it will take the ACT test.
# These students would have a higher chance of scoring well on the ACT test. This would explain the good ACT scores despite low ACT participation.
#
# With mandatory SAT testing, students who have yet to fully prepare for the SAT test will also have to sit for the test and they are more likely to score lower. This would explain the lower SAT scores despite high SAT participation.

# %% [markdown]
# The 5 states that have the highest average SAT participation rates are:
# * Connecticut
# * Delaware
# * Michigan
# * Idaho
# * Maine

# %%
#sort dataframe to contain states with lowest SAT participation rate of below 20%
low_sat_compare = sat_act_average_compare.loc[sat_act_average_compare['sat_avg_participation'] < 0.2]

low_sat_compare = low_sat_compare.sort_values('sat_avg_participation', ascending=True).head(5)

low_sat_compare
# Out:
#            state  sat_avg_participation  sat_avg_total  act_avg_participation  \
# 34  north dakota                   0.02         1267.0                   0.97
# 50       wyoming                   0.03         1242.0                   1.00
# 15          iowa                   0.03         1261.0                   0.67
# 24   mississippi                   0.03         1238.0                   1.00
# 49     wisconsin                   0.03         1289.0                   1.00
#
#     act_avg_composite
# 34               20.0
# 50               20.0
# 15               22.0
# 24               19.0
# 49               20.0

# %% [markdown]
# The 5 states that have the lowest average SAT participation rates are:
# * North Dakota
# * Wyoming
# * Iowa
# * Mississippi
# * Wisconsin

# %%
#sort dataframe to contain states with highest ACT participation rate of at least 80%
high_act_compare = sat_act_average_compare.loc[sat_act_average_compare['act_avg_participation'] >= 0.8]

high_act_compare = high_act_compare.sort_values('act_avg_participation', ascending=False).head(5)

high_act_compare
# Out:
#         state  sat_avg_participation  sat_avg_total  act_avg_participation  \
# 0     alabama                   0.06         1158.0                    1.0
# 26    montana                   0.10         1198.0                    1.0
# 49  wisconsin                   0.03         1289.0                    1.0
# 44       utah                   0.04         1159.0                    1.0
# 42  tennessee                   0.06         1226.0                    1.0
#
#     act_avg_composite
# 0                19.0
# 26               20.0
# 49               20.0
# 44               20.0
# 42               20.0

# %% [markdown]
# The 5 states that have the highest average ACT participation rates are:
# * Alabama
# * Montana
# * Wisconsin
# * Utah
# * Tennessee

# %%
#sort dataframe to contain states with lowest ACT participation rate of below 30%
low_act_compare = sat_act_average_compare.loc[sat_act_average_compare['act_avg_participation'] < 0.3]

low_act_compare = low_act_compare.sort_values('act_avg_participation', ascending=True).head(5)

low_act_compare
# Out:
#             state  sat_avg_participation  sat_avg_total  \
# 19          maine                   0.98         1013.0
# 7        delaware                   1.00          993.0
# 29  new hampshire                   0.96         1058.0
# 39   rhode island                   0.89         1025.0
# 38   pennsylvania                   0.68         1080.0
#
#     act_avg_participation  act_avg_composite
# 19                   0.07               24.0
# 7                    0.16               24.0
# 29                   0.16               25.0
# 39                   0.16               24.0
# 38                   0.20               24.0

# %% [markdown]
# The 5 states that have the lowest average SAT participation rates are:
# * Maine
# * Delaware
# * New Hampshire
# * Rhode Island
# * Pennsylvania

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#heatmap's cell size (width, height)
plt.figure(figsize = (10, 4))

#seaborn heatmap --> vmin and vmax for colormap range of values, annot set to True to display correlation values
heatmap = sns.heatmap(sat_act_average_compare.corr(), vmin=-1, vmax=1, annot=True, linewidths=0.5)

#set heatmap's title, pad to define distance of title from top of heatmap
heatmap.set_title('Correlation Heatmap of ACT and SAT Data\n(Average Participation Rate and Average Scores)', pad=10)

plt.show();

# %% [markdown]
# From the correlation heatmap, we can see that:
#
# |Names of Datas|Correlation|Description|
# |:---|:---|:---|
# |<li>SAT Participation<br><li>SAT Total Score | *Negatively correlated* | As SAT Participation increases, SAT Total Score decreases|
# |<li>ACT Participation<br><li>ACT Composite Score | *Negatively correlated* | As ACT Participation increases, ACT Composite Score decreases|
# |<li>SAT Participation<br><li>ACT Participation | *Negatively correlated* | As SAT Participation increases, ACT Participation decreases|
# |<li>SAT Participation<br><li>ACT Composite Score | *Positively correlated* | As SAT Participation increases, ACT Composite Score also increases|
#
# These findings validate the trends found during the investigation done on the dataframes earlier on.

# %%
#histogram plot for SAT participation rate 2019
sat_2019_part = cleaned_data.filter(['sat_participation_2019'])

sat_2019_part_ax = sns.histplot(sat_2019_part, bins=10);

sat_2019_part_ax.set_title('Counts of SAT Participation Rate 2019', pad=10, fontsize=14);

sat_2019_part_ax.set_xlabel('SAT Participation Rate (Percent in Decimal)', fontsize=11);

sat_2019_part_ax.set_ylabel('Number of States', fontsize=11);

plt.show();

# %%
#box plot for SAT score
sat_score_box = cleaned_data.filter(['sat_total_2017', 'sat_total_2018', 'sat_total_2019'])

sat_score_box_ax = sat_score_box.plot(kind='box');

sat_score_box_ax.set_title('SAT Total Score Box Plot', pad=10, fontsize=14);

sat_score_box_ax.set_xlabel('Years 2017-2019', fontsize=12);

sat_score_box_ax.set_ylabel('Total Score', fontsize=12);

plt.show();

# %%
#create dataframe that is indexed by states for easy visualisation plotting
cleaned_data_indexed = cleaned_data.set_index('state')

cleaned_data_indexed.head()
# Out:
#             act_participation_2017  act_participation_2018  \
# state
# alabama                       1.00                    1.00
# alaska                        0.65                    0.33
# arizona                       0.62                    0.66
# arkansas                      1.00                    1.00
# california                    0.31                    0.27
#
#             act_participation_2019  sat_participation_2017  \
# state
# alabama                       1.00                    0.05
# alaska                        0.38                    0.38
# arizona                       0.73                    0.30
# arkansas                      1.00                    0.03
# california                    0.23                    0.53
#
#             sat_participation_2018  sat_participation_2019  \
# state
# alabama                       0.06                    0.07
# alaska                        0.43                    0.41
# ...

# %%
#plot bar chart of all states participation rate for all 3 years, 2017-2019
#to see if there are any states with obvious decrease in participation rate after the SAT reformatting in 2016

#SAT participation 2017-2019 dataframe
sat_part = cleaned_data_indexed.filter([
    'sat_participation_2017', 
    'sat_participation_2018', 
    'sat_participation_2019'
], axis=1)

#sort dataframe according to sat_participation_2017 data in descending order so chart comes out neater
sat_part = sat_part.sort_values('sat_participation_2017', ascending=False)

#plot the bar chart
sat_part_ax = sat_part.plot(kind='bar', figsize=(18, 8));

#set chart title
sat_part_ax.set_title('SAT Participation Rate for 3 Years (2017-2019)', pad=10.0, fontsize=18);

#set chart x-axis labels
sat_part_ax.set_xlabel('States', fontsize=15);

#set chart y-axis labels
sat_part_ax.set_ylabel('Participation Rate (Percentage in Decimal)', fontsize=15);

#set legend
sat_part_ax.legend(fontsize=13)

plt.show();

# %%
#west virginia, colorado and illinois has drastic increase in SAT participation. pull data on the participation rates
sat_part.loc[['west virginia', 'colorado', 'illinois']]
# Out:
#                sat_participation_2017  sat_participation_2018  \
# state
# west virginia                    0.14                    0.28
# colorado                         0.11                    1.00
# illinois                         0.09                    0.99
#
#                sat_participation_2019
# state
# west virginia                    0.99
# colorado                         1.00
# illinois                         1.00

# %% [markdown]
# The SAT participation rate seems to be quite stable and have increased slightly in most cases over the 3 years from 2017 to 2019.
#
# However, there are 3 states with drastic increase in SAT participation rates:
# * West Virginia
# * Colorado
# * Illinois
#
# These 3 originally had less than 20% SAT participation rate in 2017, but by 2019, all three states had achieved SAT participation rate of at least 99%.
#
# The reason behind this is that the 3 states implemented the SAT test as the statewide standardised test, making it mandatory for students from these states to participate ([*West Virginia*](https://www.wsaz.com/content/news/All-WVa-high-school-juniors-to-begin-taking-SAT-exam-beginning-Spring-2018-444248263.html), [*Colorado*](https://www.testive.com/colorado-sat-change-2017/), [*Illinois*](https://www.testive.com/illinois/)).

# %%
#create dataframe for 5 states that has highest SAT average participation, keep only state and total score columns
sat_high_part = cleaned_data.sort_values('sat_avg_participation', ascending=False).iloc[:5, :]

sat_high_part.loc[:, ['state', 'sat_avg_participation']]
# Out:
#           state  sat_avg_participation
# 6   connecticut                   1.00
# 7      delaware                   1.00
# 22     michigan                   1.00
# 19        maine                   0.98
# 12        idaho                   0.98

# %%
#keep only state and total score columns
#index the dataframe by state and transpose so that x-axis (rows) will be scores when plotted out
sat_high_part_indexed = sat_high_part.filter([
    'state', 
    'sat_total_2017', 
    'sat_total_2018', 
    'sat_total_2019'
]).set_index('state').transpose()

sat_high_part_indexed
# Out:
# state           connecticut  delaware  michigan  maine  idaho
# sat_total_2017         1041       996      1005   1012   1005
# sat_total_2018         1053       998      1011   1013   1001
# sat_total_2019         1046       985      1003   1013    993

# %%
#create dataframe for 5 states that has lowest SAT average participation, keep only state and total score columns
sat_low_part = cleaned_data.sort_values('sat_avg_participation', ascending=True).iloc[:5, :]

sat_low_part.loc[:, ['state', 'sat_avg_participation']]
# Out:
#            state  sat_avg_participation
# 34  north dakota                   0.02
# 50       wyoming                   0.03
# 41  south dakota                   0.03
# 27      nebraska                   0.03
# 49     wisconsin                   0.03

# %%
#keep only state and total score columns
#index the dataframe by state and transpose so that x-axis (rows) will be scores when plotted out
sat_low_part_indexed = sat_low_part.filter([
    'state', 
    'sat_total_2017', 
    'sat_total_2018', 
    'sat_total_2019'
]).set_index('state').transpose()

sat_low_part_indexed
# Out:
# state           north dakota  wyoming  south dakota  nebraska  wisconsin
# sat_total_2017          1256     1230          1216      1253       1291
# sat_total_2018          1283     1257          1240      1252       1294
# sat_total_2019          1263     1238          1268      1260       1283

# %%
#combine both dataframes together for plotting
sat_both_part_indexed = pd.concat([sat_low_part_indexed, sat_high_part_indexed], axis=1)

#plot line plot to show difference in scores over 2017-2019
#10 states used in total for visualisation: 5 highest SAT participation states and 5 lowest SAT participation states
sat_both_part_indexed_ax = sat_both_part_indexed.plot(kind='line');

#set plot title
sat_both_part_indexed_ax.set_title(
    'Low SAT Participation yields High SAT Score\nHigh SAT Participation yields Low SAT Score', 
    pad=15.0, 
    fontsize=14
);

#set plot x-axis labels
sat_both_part_indexed_ax.set_xlabel('Year', fontsize=12);

#set plot y-axis labels
sat_both_part_indexed_ax.set_ylabel('SAT Score', fontsize=12);

#formatting the legend box so that is is outside the graph
#split graph into 2 columns: 1 column for 5 lowest SAT participation states, 1 column for 5 highest SAT participation states
sat_both_part_indexed_ax.legend(
    bbox_to_anchor=(1.03, 1), 
    loc=2, 
    title='Low SAT Participation States | High SAT Participation States', 
    ncol=2, 
    borderaxespad=0.0,
    handletextpad=0.5
);

plt.show();

# %%
#create dataframe for 5 states that has highest ACT average participation, keep only state and total score columns
act_high_part = cleaned_data.sort_values('act_avg_participation', ascending=False).iloc[:5, :]

act_high_part.loc[:, ['state', 'act_avg_participation']]
# Out:
#         state  act_avg_participation
# 0     alabama                    1.0
# 17   kentucky                    1.0
# 49  wisconsin                    1.0
# 44       utah                    1.0
# 42  tennessee                    1.0

# %%
#keep only state and total score columns
#index the dataframe by state and transpose so that x-axis (rows) will be scores when plotted out
act_high_part_indexed = act_high_part.filter([
    'state', 
    'act_composite_2017', 
    'act_composite_2018', 
    'act_composite_2019'
]).set_index('state').transpose()

act_high_part_indexed
# Out:
# state               alabama  kentucky  wisconsin  utah  tennessee
# act_composite_2017     19.2      20.0       20.5  20.3       19.8
# act_composite_2018     19.1      20.2       20.5  20.4       19.6
# act_composite_2019     18.9      19.8       20.3  20.3       19.4

# %%
#create dataframe for 5 states that has lowest ACT average participation, keep only state and total score columns
act_low_part = cleaned_data.sort_values('act_avg_participation', ascending=True).iloc[:5, :]

act_low_part.loc[:, ['state', 'act_avg_participation']]
# Out:
#             state  act_avg_participation
# 19          maine                   0.07
# 29  new hampshire                   0.16
# 7        delaware                   0.16
# 39   rhode island                   0.16
# 38   pennsylvania                   0.20

# %%
#keep only state and total score columns
#index the dataframe by state and transpose so that x-axis (rows) will be scores when plotted out
act_low_part_indexed = act_low_part.filter([
    'state', 
    'act_composite_2017', 
    'act_composite_2018', 
    'act_composite_2019'
]).set_index('state').transpose()

act_low_part_indexed
# Out:
# state               maine  new hampshire  delaware  rhode island  pennsylvania
# act_composite_2017   24.3           25.5      24.1          24.0          23.7
# act_composite_2018   24.0           25.1      23.8          24.2          23.5
# act_composite_2019   24.3           25.0      24.1          24.7          23.6

# %%
#combine both ACT dataframes together for plotting
act_both_part_indexed = pd.concat([act_low_part_indexed, act_high_part_indexed], axis=1)

#plot line plot to show difference in scores over 2017-2019
#10 states used in total for visualisation: 5 highest ACT participation states and 5 lowest ACT participation states
act_both_part_indexed_ax = act_both_part_indexed.plot(kind='line');

#set plot title
act_both_part_indexed_ax.set_title(
    'Low ACT Participation yields High ACT Score\nHigh ACT Participation yields Low ACT Score',
    pad=15.0, 
    fontsize=14
);

#set plot x-axis labels
act_both_part_indexed_ax.set_xlabel('Year', fontsize=12);

#set plot y-axis labels
act_both_part_indexed_ax.set_ylabel('ACT Score', fontsize=12);

#formatting the legend box so that is is outside the graph
#split graph into 2 columns: 1 column for 5 lowest ACT participation states, 1 column for 5 highest ACT participation states
act_both_part_indexed_ax.legend(
    bbox_to_anchor=(1.03, 1), 
    loc=2, 
    title='Low ACT Participation States | High ACT Participation States', 
    ncol=2, 
    borderaxespad=0.0,
    handletextpad=0.5
);

plt.show();

# %%
#plot scatter plot to visualise the association between ACT score and SAT participation rate
scatter_ax = sns.scatterplot(x='sat_participation_2019', y='act_participation_2019', data=cleaned_data);

#set scatter plot title
scatter_ax.set_title('ACT Participation decrease as \nSAT Participation increases (2019 data)', pad=13.0, fontsize=14);

#set plot x-axis labels
scatter_ax.set_xlabel('SAT Participation (Percentage in Decimal)', fontsize=11);

#set plot y-axis labels
scatter_ax.set_ylabel('ACT Participation\n(Percentage in Decimal)', fontsize=11);

plt.show();

# %% [markdown]
# Interpretation: The scatter plot above shows that as there is an increase in SAT participation, the ACT participation tends to decrease and vice versa.
#
# This proves that ACT Participation and SAT Participation are negatively correlated.

# %%
#plot scatter plot to visualise the association between ACT score and SAT participation rate
scatter_ax = sns.scatterplot(x='sat_participation_2019', y='act_composite_2019', data=cleaned_data);

#set scatter plot title
scatter_ax.set_title('ACT Score increase as \nSAT Participation increases (2019 data)', pad=10.0, fontsize=14);

#set plot x-axis labels
scatter_ax.set_xlabel('SAT Participation (Percentage in Decimal)', fontsize=11);

#set plot y-axis labels
scatter_ax.set_ylabel('ACT Composite Score', fontsize=11);

plt.show();

# %% [markdown]
# Interpretation: The scatter plot above shows that as there is an increase in SAT participation, the ACT composite score also tends to increase.
#
# This proves that ACT Composite Score and SAT Participation are positively correlated.
#
#
# Focus is on the top right hand side of the plot, where ACT scores are above 24 points. States that achieve an ACT score of 24 and above all have SAT participation that is above 80%.
#
# This validates the point made earlier that for states with high SAT participation, likely due to mandatory SAT testing, generally only students who prefers and are fully prepared for the ACT test will take the ACT test. They have a higher chance of scoring well and as a result, there are good ACT scores in these states.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Since the reformatting of the SAT test in March 2016, the participation rates of the different states over the course of 3 years, from 2017 to 2019, have remained fairly constant with no obvious drops. There have been 3 states with drastic increases in their participation rates, mainly due to the states' implementation of mandatory SAT testing after 2017 ([*West Virginia*](https://www.wsaz.com/content/news/All-WVa-high-school-juniors-to-begin-taking-SAT-exam-beginning-Spring-2018-444248263.html), [*Colorado*](https://www.testive.com/colorado-sat-change-2017/), [*Illinois*](https://www.testive.com/illinois/)).
#
# Looking into the trends between the SAT and ACT participation rates and scores, a few conclusions can be drawn with regards to the SAT test, which is the main focus of this project:
# * States with higher SAT participation generally scores lower on the SAT test
#     * *likely due to mandatory SAT testing which includes students who are not fully prepared and more likely to score lower*
# * States with higher SAT participation generally scores well on the ACT test
#     * *likely due to mandatory SAT testing, with only students fully prepared for ACT choosing to also take the ACT test and score well*
# * As SAT participation increases, the ACT participation decreases and vice versa
#     * *likely due to mandatory SAT testing, so number of students who takes ACT will decrease as it is optional*

# %% [markdown]
# Based on the results of the investigations, there are 3 recommendations for improving the SAT participation rates:
# 1. The College Board can focus on working to sign contracts with the Department of Education of states without mandatory SAT testing, especially if the state's current contract with ACT is expiring
# 2. Consider giving discounts or promotions to students taking the SAT tests as the tests can get costly especially if the student intends to apply to many colleges
# 3. Place more focus on states with low SAT scores and states with high ACT scores to provide support and increase confidence in SAT
